# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv(r'C:\Users\Gagan\Downloads\temperature.csv')
data
# Out:
#       station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 0         1.0  30-06-2013          28.7          21.4    58.255688
# 1         2.0  30-06-2013          31.9          21.6    52.263397
# 2         3.0  30-06-2013          31.6          23.3    48.690479
# 3         4.0  30-06-2013          32.0          23.4    58.239788
# 4         5.0  30-06-2013          31.4          21.9    56.174095
# ...       ...         ...           ...           ...          ...
# 7747     23.0  30-08-2017          23.3          17.1    26.741310
# 7748     24.0  30-08-2017          23.3          17.7    24.040634
# 7749     25.0  30-08-2017          23.2          17.4    22.933014
# 7750      NaN         NaN          20.0          11.3    19.794666
# 7751      NaN         NaN          37.6          29.9    98.524734
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  \
# 0       91.116364         28.074101         23.006936   6.818887   69.451805
# ...

# %%
data.shape
# Out:
# (7752, 25)

# %%
data.head(10)
# Out:
#    station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0  30-06-2013          28.7          21.4    58.255688    91.116364
# 1      2.0  30-06-2013          31.9          21.6    52.263397    90.604721
# 2      3.0  30-06-2013          31.6          23.3    48.690479    83.973587
# 3      4.0  30-06-2013          32.0          23.4    58.239788    96.483688
# 4      5.0  30-06-2013          31.4          21.9    56.174095    90.155128
# 5      6.0  30-06-2013          31.9          23.5    52.437126    85.307251
# 6      7.0  30-06-2013          31.4          24.4    56.287189    81.019760
# 7      8.0  30-06-2013          32.1          23.6    52.326218    78.004539
# 8      9.0  30-06-2013          31.4          22.0    55.338791    80.784607
# 9     10.0  30-06-2013          31.6          20.5    56.651203    86.849632
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  ...  LDAPS_PPT2  \
# ...

# %%
data.tail(10)
# Out:
#       station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 7742     18.0  30-08-2017          23.3          18.2    30.259682
# 7743     19.0  30-08-2017          22.6          15.0    25.536045
# 7744     20.0  30-08-2017          22.7          15.9    38.216373
# 7745     21.0  30-08-2017          23.1          17.8    24.688997
# 7746     22.0  30-08-2017          22.5          17.4    30.094858
# 7747     23.0  30-08-2017          23.3          17.1    26.741310
# 7748     24.0  30-08-2017          23.3          17.7    24.040634
# 7749     25.0  30-08-2017          23.2          17.4    22.933014
# 7750      NaN         NaN          20.0          11.3    19.794666
# 7751      NaN         NaN          37.6          29.9    98.524734
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  \
# 7742    86.565193         26.474403         17.289157   6.522731   94.203783
# ...

# %%
data.dtypes
# Out:
# station             float64
# Date                 object
# Present_Tmax        float64
# Present_Tmin        float64
# LDAPS_RHmin         float64
# LDAPS_RHmax         float64
# LDAPS_Tmax_lapse    float64
# LDAPS_Tmin_lapse    float64
# LDAPS_WS            float64
# LDAPS_LH            float64
# LDAPS_CC1           float64
# LDAPS_CC2           float64
# LDAPS_CC3           float64
# LDAPS_CC4           float64
# LDAPS_PPT1          float64
# LDAPS_PPT2          float64
# LDAPS_PPT3          float64
# LDAPS_PPT4          float64
# lat                 float64
# lon                 float64
# DEM                 float64
# Slope               float64
# Solar radiation     float64
# Next_Tmax           float64
# Next_Tmin           float64
# dtype: object

# %%
data.isna().sum()
# Out:
# station              2
# Date                 2
# Present_Tmax        70
# Present_Tmin        70
# LDAPS_RHmin         75
# LDAPS_RHmax         75
# LDAPS_Tmax_lapse    75
# LDAPS_Tmin_lapse    75
# LDAPS_WS            75
# LDAPS_LH            75
# LDAPS_CC1           75
# LDAPS_CC2           75
# LDAPS_CC3           75
# LDAPS_CC4           75
# LDAPS_PPT1          75
# LDAPS_PPT2          75
# LDAPS_PPT3          75
# LDAPS_PPT4          75
# lat                  0
# lon                  0
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmax           27
# Next_Tmin           27
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7752 entries, 0 to 7751
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   station           7750 non-null   float64
#  1   Date              7750 non-null   object
#  2   Present_Tmax      7682 non-null   float64
#  3   Present_Tmin      7682 non-null   float64
#  4   LDAPS_RHmin       7677 non-null   float64
#  5   LDAPS_RHmax       7677 non-null   float64
#  6   LDAPS_Tmax_lapse  7677 non-null   float64
#  7   LDAPS_Tmin_lapse  7677 non-null   float64
#  8   LDAPS_WS          7677 non-null   float64
#  9   LDAPS_LH          7677 non-null   float64
#  10  LDAPS_CC1         7677 non-null   float64
#  11  LDAPS_CC2         7677 non-null   float64
#  12  LDAPS_CC3         7677 non-null   float64
#  13  LDAPS_CC4         7677 non-null   float64
#  14  LDAPS_PPT1        7677 non-null   float64
#  15  LDAPS_PPT2        7677 non-null   float64
# ...

# %%
for i in data.columns:
    print(data[i].value_counts())
    print('\n')
# Out:
# 1.0     310
# 14.0    310
# 24.0    310
# 23.0    310
# 22.0    310
# 21.0    310
# 20.0    310
# 19.0    310
# 18.0    310
# 17.0    310
# 16.0    310
# 15.0    310
# 13.0    310
# 2.0     310
# 12.0    310
# 11.0    310
# 10.0    310
# 9.0     310
# 8.0     310
# 7.0     310
# 6.0     310
# 5.0     310
# 4.0     310
# 3.0     310
# 25.0    310
# Name: station, dtype: int64
#
#
# 30-06-2013    25
# 18-07-2016    25
# 25-07-2016    25
# 24-07-2016    25
# 23-07-2016    25
#               ..
# 09-08-2014    25
# 08-08-2014    25
# 07-08-2014    25
# 06-08-2014    25
# 30-08-2017    25
# Name: Date, Length: 310, dtype: int64
#
#
# 31.4    112
# 29.4    111
# 29.1    108
# 29.7    107
# 31.9    105
#        ...
# 36.9      1
# 21.2      1
# 20.1      1
# 36.4      1
# 20.3      1
# Name: Present_Tmax, Length: 167, dtype: int64
#
#
# 24.0    161
# 23.8    153
# 23.1    144
# 23.5    143
# 23.3    142
#        ...
# 13.6      1
# 14.2      1
# 29.1      1
# 29.7      1
# 15.0      1
# ...

# %%
sns.heatmap(data.isna())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # observation
# 1.We have check the shape of the data (7752 rows and 25column)
# 2.We have check the data types and all the data are in float and in date column the data type is object so we need to
#   convert the data type object to date time format
# 3.We have check the null values and there are null values present in the data set
#   so we will fill the nan values in the data set
# 4.Also we have draw heatmap to show the nan value
# 5.We will drop the station column because its just a values just like index number

# %%
data.drop(['station','Date'],axis=1,inplace=True)

# %%
data
# Out:
#       Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  LDAPS_Tmax_lapse  \
# 0             28.7          21.4    58.255688    91.116364         28.074101
# 1             31.9          21.6    52.263397    90.604721         29.850689
# 2             31.6          23.3    48.690479    83.973587         30.091292
# 3             32.0          23.4    58.239788    96.483688         29.704629
# 4             31.4          21.9    56.174095    90.155128         29.113934
# ...            ...           ...          ...          ...               ...
# 7747          23.3          17.1    26.741310    78.869858         26.352081
# 7748          23.3          17.7    24.040634    77.294975         27.010193
# 7749          23.2          17.4    22.933014    77.243744         27.939516
# 7750          20.0          11.3    19.794666    58.936283         17.624954
# 7751          37.6          29.9    98.524734   100.000153         38.542255
#
# ...

# %%
data.dtypes
# Out:
# Present_Tmax        float64
# Present_Tmin        float64
# LDAPS_RHmin         float64
# LDAPS_RHmax         float64
# LDAPS_Tmax_lapse    float64
# LDAPS_Tmin_lapse    float64
# LDAPS_WS            float64
# LDAPS_LH            float64
# LDAPS_CC1           float64
# LDAPS_CC2           float64
# LDAPS_CC3           float64
# LDAPS_CC4           float64
# LDAPS_PPT1          float64
# LDAPS_PPT2          float64
# LDAPS_PPT3          float64
# LDAPS_PPT4          float64
# lat                 float64
# lon                 float64
# DEM                 float64
# Slope               float64
# Solar radiation     float64
# Next_Tmax           float64
# Next_Tmin           float64
# dtype: object

# %%
from sklearn.impute import SimpleImputer
from sklearn.compose import make_column_transformer

# %%
si=SimpleImputer()
df_con=make_column_transformer(
(si,['Present_Tmax','Present_Tmin','LDAPS_RHmin','LDAPS_RHmax',
     'LDAPS_Tmax_lapse','LDAPS_Tmin_lapse','LDAPS_WS','LDAPS_LH', 'LDAPS_CC1', 'LDAPS_CC2',
     'LDAPS_CC3','LDAPS_CC4','LDAPS_PPT1','LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4','Next_Tmax','Next_Tmin']),remainder='passthrough')

# %%
encoded=pd.DataFrame(df_con.fit_transform(data))
encoded
# Out:
#         0     1          2           3          4          5          6   \
# 0     28.7  21.4  58.255688   91.116364  28.074101  23.006936   6.818887
# 1     31.9  21.6  52.263397   90.604721  29.850689  24.035009   5.691890
# 2     31.6  23.3  48.690479   83.973587  30.091292  24.565633   6.138224
# 3     32.0  23.4  58.239788   96.483688  29.704629  23.326177   5.650050
# 4     31.4  21.9  56.174095   90.155128  29.113934  23.486480   5.735004
# ...    ...   ...        ...         ...        ...        ...        ...
# 7747  23.3  17.1  26.741310   78.869858  26.352081  18.775678   6.148918
# 7748  23.3  17.7  24.040634   77.294975  27.010193  18.733519   6.542819
# 7749  23.2  17.4  22.933014   77.243744  27.939516  18.522965   7.289264
# 7750  20.0  11.3  19.794666   58.936283  17.624954  14.272646   2.882580
# 7751  37.6  29.9  98.524734  100.000153  38.542255  29.619342  21.857621
#
#               7         8         9   ...         13         14         15  \
# ...

# %%
df=pd.DataFrame(df_con.fit_transform(data),columns=['Present_Tmax','Present_Tmin','LDAPS_RHmin','LDAPS_RHmax',
     'LDAPS_Tmax_lapse','LDAPS_Tmin_lapse','LDAPS_WS','LDAPS_LH', 'LDAPS_CC1', 'LDAPS_CC2',
     'LDAPS_CC3','LDAPS_CC4','LDAPS_PPT1','LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4','Next_Tmax','Next_Tmin','lat','lon','Dem','Slope','Solar radiation'])

# %%
df
# Out:
#       Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  LDAPS_Tmax_lapse  \
# 0             28.7          21.4    58.255688    91.116364         28.074101
# 1             31.9          21.6    52.263397    90.604721         29.850689
# 2             31.6          23.3    48.690479    83.973587         30.091292
# 3             32.0          23.4    58.239788    96.483688         29.704629
# 4             31.4          21.9    56.174095    90.155128         29.113934
# ...            ...           ...          ...          ...               ...
# 7747          23.3          17.1    26.741310    78.869858         26.352081
# 7748          23.3          17.7    24.040634    77.294975         27.010193
# 7749          23.2          17.4    22.933014    77.243744         27.939516
# 7750          20.0          11.3    19.794666    58.936283         17.624954
# 7751          37.6          29.9    98.524734   100.000153         38.542255
#
# ...

# %%
df.describe()
# Out:
#        Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  LDAPS_Tmax_lapse  \
# count   7752.000000   7752.000000  7752.000000  7752.000000       7752.000000
# mean      29.768211     23.225059    56.759372    88.374804         29.613447
# std        2.956557      2.403036    14.596973     7.157124          2.932898
# min       20.000000     11.300000    19.794666    58.936283         17.624954
# 25%       27.800000     21.700000    46.046162    84.316923         27.693091
# 50%       29.900000     23.400000    55.313244    89.699505         29.662273
# 75%       32.000000     24.900000    67.038254    93.704500         31.683819
# max       37.600000     29.900000    98.524734   100.000153         38.542255
#
#        LDAPS_Tmin_lapse     LDAPS_WS     LDAPS_LH    LDAPS_CC1    LDAPS_CC2  \
# count       7752.000000  7752.000000  7752.000000  7752.000000  7752.000000
# mean          23.512589     7.097875    62.505019     0.368774     0.356080
# ...

# %% [markdown]
# # observation
# We have remove the date and station and date column
# We have fill the nan value through the simple imputer technique
# Now we will move towards the EDA

# %%
sns.countplot(x='Next_Tmax',data=df)
# Out:
# <AxesSubplot:xlabel='Next_Tmax', ylabel='count'>

# %%
sns.countplot(x='Next_Tmin',data=df)
# Out:
# <AxesSubplot:xlabel='Next_Tmin', ylabel='count'>

# %%
plt.figure(figsize=(18, 6))
plt.plot(df["Next_Tmax"],label="Next_Tmax")
plt.plot(df["Next_Tmin"],label="Next_Tmin")
plt.legend()
plt.show()

# %% [markdown]
# # observation
# In the above graph we can clearly say that
# in Next_Tmax there is a hike at some interval of the dataset and at some interval it decreases at some point of time
# In Next_Tmin its a same that there is hike at some interval but at the same time there is drop
# But there is a common point in both that there is drop at the end of the graph for both the column

# %% [markdown]
# # LETS DO SOME ANOTHER ANALYSIS

# %%
plt.figure(figsize=(18,6))
sns.scatterplot(x='Present_Tmax',y='Present_Tmin',data=df)
# Out:
# <AxesSubplot:xlabel='Present_Tmax', ylabel='Present_Tmin'>

# %% [markdown]
# # In the graph we can clearly say that when one factor increases the other factor also increases so there might be correlation between them Lets see

# %%
plt.figure(figsize=(18,6))
sns.scatterplot(x='LDAPS_RHmin',y='LDAPS_RHmax',data=df)
# Out:
# <AxesSubplot:xlabel='LDAPS_RHmin', ylabel='LDAPS_RHmax'>

# %% [markdown]
# # Same result...When x axis increases y axis also increases Lets check with our target variable and compare

# %% [markdown]
# # Lets compare each and every feature with corresponding label

# %%
data=df.corr()
data
# Out:
#                   Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# Present_Tmax          1.000000      0.618760    -0.204571    -0.301787
# Present_Tmin          0.618760      1.000000     0.123143    -0.015140
# LDAPS_RHmin          -0.204571      0.123143     1.000000     0.579141
# LDAPS_RHmax          -0.301787     -0.015140     0.579141     1.000000
# LDAPS_Tmax_lapse      0.570129      0.464151    -0.564580    -0.373404
# LDAPS_Tmin_lapse      0.623496      0.762993     0.089476    -0.114143
# LDAPS_WS             -0.121820     -0.034675     0.294361     0.135333
# LDAPS_LH              0.135463     -0.009258    -0.070858     0.238579
# LDAPS_CC1            -0.311805      0.084447     0.613818     0.436652
# LDAPS_CC2            -0.213791      0.090263     0.745443     0.391330
# LDAPS_CC3            -0.144018     -0.002772     0.689679     0.226957
# LDAPS_CC4            -0.140729     -0.044335     0.514075     0.130619
# ...

# %%
plt.figure(figsize=(18,10))
sns.heatmap(data,annot=True,cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # observation
# in heatmap we can see correlation with each other
# all feature is having relation with each other whether its positive or negetive it is having

# %%
X=df.drop(['Next_Tmax','Next_Tmin'],axis=1,)
Y=df['Next_Tmax']
Z=df['Next_Tmin']

# %%
plt.figure(figsize=(20,25),facecolor='pink')
plotnumber=1
for columns in X:
    if plotnumber<=22:
        ax=plt.subplot(11,11,plotnumber)
        sns.scatterplot(Y,X[columns])
       
    plotnumber+=1
plt.show()

# %%
plt.figure(figsize=(20,25),facecolor='pink')
plotnumber=1
for columns in X:
    if plotnumber<=22:
        ax=plt.subplot(11,11,plotnumber)
        sns.scatterplot(Z,X[columns])
       
    plotnumber+=1
plt.show()

# %%
plt.figure(figsize=(20,25),facecolor='pink')
plotnumber=1
for columns in X:
    if plotnumber<=22:
        ax=plt.subplot(11,11,plotnumber)
        sns.boxplot(X[columns])
        plt.xlabel(columns,fontsize=10)
    plotnumber+=1
plt.show()

# %% [markdown]
# # observation
# we have plot the all the feature with there corresponding label
# through which it is clear that some of the feature are in a staraight line and contibuting to their feature and some are not
# so there must be outlier present
#
# Also plot the  boxplot to check the outliers and they are present but we will not remove because outliers are present in
# those column in which we have fill nan value so we will not remove them

# %% [markdown]
# # NOW LETS IMPORT THE NECESSARY LIBRARIES FOR MODEL BUILDING

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
X.shape
# Out:
# (7752, 21)

# %%
Y.shape
# Out:
# (7752,)

# %%
scaler=StandardScaler()
X_Scaled=scaler.fit_transform(X)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state=82, test_size=.25)
print('Training feature matrix size:',X_train.shape)
print('Training target vector size:',Y_train.shape)
print('Test feature matrix size:',X_test.shape)
print('Test target vector size:',Y_test.shape)
# Out:
# Training feature matrix size: (5814, 21)
# Training target vector size: (5814,)
# Test feature matrix size: (1938, 21)
# Test target vector size: (1938,)

# %%
log_reg=LinearRegression()
log_reg.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_pred=log_reg.predict(X_test)
print('Predicted result price:\n', y_pred)
print(r2_score(Y_test,y_pred))
print('Mean absolute error :', mean_absolute_error(Y_test,y_pred))
print('Mean squared error :', mean_squared_error(Y_test,y_pred))
# Out:
# Predicted result price:
#  [32.084476   36.52194862 30.55380388 ... 27.80912038 31.05476852
#  33.29147583]
# 0.7696870738774986
# Mean absolute error : 1.1508994068892606
# Mean squared error : 2.2479642660548476

# %%
dtc = DecisionTreeRegressor()
ad=AdaBoostRegressor()

# %%
dtc.fit(X_train,Y_train)
Y_pred=dtc.predict(X_test)
print('Predicted result price:\n', y_pred)
print(r2_score(Y_test,y_pred))
print('Mean absolute error :', mean_absolute_error(Y_test,Y_pred))
print('Mean squared error :', mean_squared_error(Y_test,Y_pred))
# Out:
# Predicted result price:
#  [32.084476   36.52194862 30.55380388 ... 27.80912038 31.05476852
#  33.29147583]
# 0.7696870738774986
# Mean absolute error : 1.0746002785375777
# Mean squared error : 2.237830130388976

# %%
ad.fit(X_train,Y_train)
pred=ad.predict(X_test)
print('Predicted result price:\n', y_pred)
print(r2_score(Y_test,y_pred))
print('Mean absolute error :', mean_absolute_error(Y_test,pred))
print('Mean squared error :', mean_squared_error(Y_test,pred))
# Out:
# Predicted result price:
#  [32.084476   36.52194862 30.55380388 ... 27.80912038 31.05476852
#  33.29147583]
# 0.7696870738774986
# Mean absolute error : 1.2846226165938526
# Mean squared error : 2.4813253143333043

# %% [markdown]
# # Lets do hyperparameter tunning

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
params={'n_estimators':[45,50,60,70], 'learning_rate':[0.25,0.30,0.40]}

# %%
rand_srch=RandomizedSearchCV(ad,cv=5,param_distributions=params)

# %%
rand_srch.fit(X_train,Y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=AdaBoostRegressor(),
#                    param_distributions={'learning_rate': [0.25, 0.3, 0.4],
#                                         'n_estimators': [45, 50, 60, 70]})

# %%
rand_srch.best_estimator_
# Out:
# AdaBoostRegressor(learning_rate=0.4, n_estimators=70)

# %%
ada=AdaBoostRegressor(n_estimators=45,learning_rate=0.3)
ada.fit(X_train,Y_train)
Y_pred=ada.predict(X_test)
print(r2_score(Y_test,Y_pred))
# Out:
# 0.7491555417990897

# %% [markdown]
# # through hyperparameter tunning score is not improving
# lets try with other label that is z label

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Z, random_state=82, test_size=.25)
print('Training feature matrix size:',X_train.shape)
print('Training target vector size:',Y_train.shape)
print('Test feature matrix size:',X_test.shape)
print('Test target vector size:',Y_test.shape)
# Out:
# Training feature matrix size: (5814, 21)
# Training target vector size: (5814,)
# Test feature matrix size: (1938, 21)
# Test target vector size: (1938,)

# %%
log_reg.fit(X_train,Y_train)
y_pred=log_reg.predict(X_test)
print('Predicted result price:\n', y_pred)
print(r2_score(Y_test,y_pred))
print('Mean absolute error :', mean_absolute_error(Y_test,y_pred))
print('Mean squared error :', mean_squared_error(Y_test,y_pred))
# Out:
# Predicted result price:
#  [26.9221282  26.6768534  23.78728644 ... 20.68343346 25.09093087
#  23.71434051]
# 0.8346218286226562
# Mean absolute error : 0.7722034079824109
# Mean squared error : 1.0051775954872748

# %%
dtc.fit(X_train,Y_train)
Y_pred=dtc.predict(X_test)
print('Predicted result price:\n', y_pred)
print(r2_score(Y_test,y_pred))
print('Mean absolute error :', mean_absolute_error(Y_test,Y_pred))
print('Mean squared error :', mean_squared_error(Y_test,Y_pred))
# Out:
# Predicted result price:
#  [26.9221282  26.6768534  23.78728644 ... 20.68343346 25.09093087
#  23.71434051]
# 0.8346218286226562
# Mean absolute error : 0.8573437668032637
# Mean squared error : 1.3912783715546624

# %%
ad.fit(X_train,Y_train)
pred=ad.predict(X_test)
print('Predicted result price:\n', y_pred)
print(r2_score(Y_test,y_pred))
print('Mean absolute error :', mean_absolute_error(Y_test,pred))
print('Mean squared error :', mean_squared_error(Y_test,pred))
# Out:
# Predicted result price:
#  [26.9221282  26.6768534  23.78728644 ... 20.68343346 25.09093087
#  23.71434051]
# 0.8346218286226562
# Mean absolute error : 0.8934323876409812
# Mean squared error : 1.245807848484348
