# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/DSData/master/winequality-red.csv")

# %%
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
data.head(30)
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.4             0.700         0.00             1.9      0.076
# 1             7.8             0.880         0.00             2.6      0.098
# 2             7.8             0.760         0.04             2.3      0.092
# 3            11.2             0.280         0.56             1.9      0.075
# 4             7.4             0.700         0.00             1.9      0.076
# 5             7.4             0.660         0.00             1.8      0.075
# 6             7.9             0.600         0.06             1.6      0.069
# 7             7.3             0.650         0.00             1.2      0.065
# 8             7.8             0.580         0.02             2.0      0.073
# 9             7.5             0.500         0.36             6.1      0.071
# 10            6.7             0.580         0.08             1.8      0.097
# ...

# %%
data.tail(30)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1569            6.2             0.510         0.14             1.9      0.056
# 1570            6.4             0.360         0.53             2.2      0.230
# 1571            6.4             0.380         0.14             2.2      0.038
# 1572            7.3             0.690         0.32             2.2      0.069
# 1573            6.0             0.580         0.20             2.4      0.075
# 1574            5.6             0.310         0.78            13.9      0.074
# 1575            7.5             0.520         0.40             2.2      0.060
# 1576            8.0             0.300         0.63             1.6      0.081
# 1577            6.2             0.700         0.15             5.1      0.076
# 1578            6.8             0.670         0.15             1.8      0.118
# 1579            6.2             0.560         0.09             1.7      0.053
# ...

# %%
data.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
data.shape
# Out:
# (1599, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
for i in data.columns:
    print(data[i].value_counts())
    print("\n")
# Out:
# 7.2     67
# 7.1     57
# 7.8     53
# 7.5     52
# 7.0     50
#         ..
# 13.5     1
# 13.8     1
# 13.4     1
# 4.7      1
# 5.5      1
# Name: fixed acidity, Length: 96, dtype: int64
#
#
# 0.600    47
# 0.500    46
# 0.430    43
# 0.590    39
# 0.360    38
#          ..
# 1.035     1
# 0.565     1
# 1.130     1
# 1.115     1
# 1.090     1
# Name: volatile acidity, Length: 143, dtype: int64
#
#
# 0.00    132
# 0.49     68
# 0.24     51
# 0.02     50
# 0.26     38
#        ...
# 0.72      1
# 0.62      1
# 0.75      1
# 1.00      1
# 0.78      1
# Name: citric acid, Length: 80, dtype: int64
#
#
# 2.00     156
# 2.20     131
# 1.80     129
# 2.10     128
# 1.90     117
#         ...
# 4.25       1
# 2.85       1
# 3.45       1
# 2.35       1
# 13.90      1
# Name: residual sugar, Length: 91, dtype: int64
#
#
# 0.080    66
# 0.074    55
# 0.076    51
# 0.078    51
# 0.084    49
#          ..
# 0.108     1
# 0.148     1
# 0.143     1
# 0.222     1
# 0.230     1
# ...

# %%
data.nunique()
# Out:
# fixed acidity            96
# volatile acidity        143
# citric acid              80
# residual sugar           91
# chlorides               153
# free sulfur dioxide      60
# total sulfur dioxide    144
# density                 436
# pH                       89
# sulphates                96
# alcohol                  65
# quality                   6
# dtype: int64

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [markdown]
# # observations
# #no null values are present thats great #mean value is greater than median(50%)in fixed acidity,free sulphur dioxide,total sulphur dioxide that means data is right squed as we can also seen in the distribution plot and scatter plot #also ther is difference between 75% and max in various column that means some outliers are also present

# %%
plt.figure(figsize=(20,25),facecolor='yellow')
plotnumber=1

for column in data:
    if plotnumber<=12:
        ax=plt.subplot(6,6,plotnumber)
        sns.distplot(data[column])
        plt.xlabel(column,fontsize=10)
    
    plotnumber+=1
plt.show()

# %%
sns.heatmap(data)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # observation
# in the heat map we observe that free sulphur dioxide and total sulphur dioxide has high correlation between them so we should drop the one of the column

# %%
data=data.drop('total sulfur dioxide',axis=1,)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [19], in <cell line: 1>()
# ----> 1 data=data.drop('total sulfur dioxide',axis=1,)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
# ...

# %%
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
data.skew()
# Out:
# fixed acidity          0.982751
# volatile acidity       0.671593
# citric acid            0.318337
# residual sugar         4.540655
# chlorides              5.680347
# free sulfur dioxide    1.250567
# density                0.071288
# pH                     0.193683
# sulphates              2.428672
# alcohol                0.860829
# quality                0.217802
# dtype: float64

# %%
df_feature=data.drop('quality',axis=1)

# %%
plt.figure(figsize=(20,25),facecolor='blue')
graph=1

for column in df_feature:
    if graph<=11:
        ax=plt.subplot(6,5,graph)
        sns.boxplot(data=df_feature[column])
        plt.xlabel(column,fontsize=20)
    
    graph+=1
plt.show()

# %% [markdown]
# # observation
# #outliers are present in all the column so we need to remove the outliers from each column we need to remove for both upper and lower outliers

# %%
from scipy.stats import zscore
z=np.abs(zscore(df_feature))
z.shape
threshold=3
print(np.where(z>3))
# Out:
# (array([  13,   14,   15,   17,   17,   19,   33,   38,   42,   43,   45,
#          57,   81,   81,   83,   86,   88,   91,   92,   95,  106,  106,
#         120,  126,  127,  142,  144,  147,  151,  151,  151,  151,  163,
#         164,  169,  169,  181,  199,  226,  226,  240,  243,  244,  258,
#         258,  274,  281,  291,  324,  325,  339,  340,  347,  374,  381,
#         391,  396,  396,  400,  400,  442,  442,  451,  467,  480,  480,
#         494,  544,  554,  554,  555,  555,  557,  557,  568,  584,  588,
#         595,  608,  614,  639,  649,  652,  652,  652,  672,  690,  692,
#         692,  695,  723,  724,  730,  754,  776,  777,  795,  821,  836,
#         837,  889,  911,  917,  923,  925,  926,  982, 1017, 1018, 1043,
#        1051, 1051, 1071, 1074, 1079, 1081, 1111, 1114, 1131, 1154, 1165,
#        1175, 1186, 1231, 1235, 1244, 1244, 1260, 1269, 1269, 1270, 1270,
#        1288, 1289, 1295, 1296, 1299, 1300, 1312, 1316, 1319, 1319, 1321,
# ...

# %%
data=data[(z<3).all(axis=1)]
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1467.000000       1467.000000  1467.000000     1467.000000
# mean        8.311929          0.524830     0.265883        2.389196
# std         1.645628          0.170263     0.191017        0.868900
# min         5.000000          0.120000     0.000000        1.200000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.200000          0.635000     0.420000        2.600000
# max        13.500000          1.040000     0.790000        6.700000
#
#          chlorides  free sulfur dioxide      density           pH  \
# count  1467.000000          1467.000000  1467.000000  1467.000000
# mean      0.081594            15.188480     0.996718     3.315787
# std       0.021222             9.386616     0.001731     0.140811
# min       0.038000             1.000000     0.991200     2.880000
# ...

# %% [markdown]
# # observation
# After applied z score method still outliers are present as shown in the graph in some of the columns
# so we need to remove in some of the columns

# %%
df_feature=data.drop('quality',axis=1)

# %%
plt.figure(figsize=(20,25),facecolor='blue')
graph=1

for column in df_feature:
    if graph<=11:
        ax=plt.subplot(6,5,graph)
        sns.boxplot(data=df_feature[column])
        plt.xlabel(column,fontsize=20)
    
    graph+=1
plt.show()

# %%
q1=data.quantile(0.25)
q3=data.quantile(0.75)
iqr=q3-q1

# %%
fc=(q3.chlorides + (1.5 * iqr.chlorides))
fc
# Out:
# 0.11749999999999998

# %%
ch=np.where(data["chlorides"] > fc)
ch
# Out:
# (array([  90,   99,  101,  105,  108,  264,  268,  269,  285,  289,  290,
#          294,  299,  300,  309,  324,  330,  359,  369,  397,  429,  430,
#          458,  461,  463,  494,  499,  500,  508,  509,  554,  560,  561,
#          574,  599,  621,  698,  699,  703,  718,  730,  753,  754,  761,
#          801,  828,  833,  871,  926,  930,  931, 1002, 1013, 1047, 1053,
#         1055, 1088, 1090, 1104, 1117, 1118, 1146, 1152, 1153, 1215, 1249,
#         1299, 1310, 1447], dtype=int64),)

# %%
data = data.drop(data.index[ch])
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
data.reset_index()
# Out:
#       index  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0         0            7.4             0.700         0.00             1.9
# 1         1            7.8             0.880         0.00             2.6
# 2         2            7.8             0.760         0.04             2.3
# 3         3           11.2             0.280         0.56             1.9
# 4         4            7.4             0.700         0.00             1.9
# ...     ...            ...               ...          ...             ...
# 1393   1594            6.2             0.600         0.08             2.0
# 1394   1595            5.9             0.550         0.10             2.2
# 1395   1596            6.3             0.510         0.13             2.3
# 1396   1597            5.9             0.645         0.12             2.0
# 1397   1598            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  density    pH  sulphates  alcohol  \
# ...

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1398.000000       1398.000000  1398.000000     1398.000000
# mean        8.272031          0.524449     0.261688        2.380830
# std         1.628319          0.171041     0.188382        0.859473
# min         5.000000          0.120000     0.000000        1.200000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.635000     0.410000        2.600000
# max        13.400000          1.040000     0.760000        6.700000
#
#          chlorides  free sulfur dioxide      density           pH  \
# count  1398.000000          1398.000000  1398.000000  1398.000000
# mean      0.078394            15.335122     0.996681     3.318519
# std       0.014337             9.354402     0.001723     0.140585
# min       0.038000             1.000000     0.991200     2.880000
# ...

# %%
cx=(q3.sulphates + (1.5 * iqr.sulphates))
cx
# Out:
# 0.9749999999999999

# %%
s=np.where(data['sulphates']>cx)
s
# Out:
# (array([  68,  130,  165,  285,  292,  309,  312,  314,  315,  316,  348,
#          405,  427,  428,  430,  443,  496,  727,  812, 1002, 1009, 1213,
#         1218], dtype=int64),)

# %%
data=data.drop(data.index[s])
data.reset_index()
# Out:
#       index  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0         0            7.4             0.700         0.00             1.9
# 1         1            7.8             0.880         0.00             2.6
# 2         2            7.8             0.760         0.04             2.3
# 3         3           11.2             0.280         0.56             1.9
# 4         4            7.4             0.700         0.00             1.9
# ...     ...            ...               ...          ...             ...
# 1370   1594            6.2             0.600         0.08             2.0
# 1371   1595            5.9             0.550         0.10             2.2
# 1372   1596            6.3             0.510         0.13             2.3
# 1373   1597            5.9             0.645         0.12             2.0
# 1374   1598            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  density    pH  sulphates  alcohol  \
# ...

# %%
plt.figure(figsize=(20,25),facecolor='yellow')
plotnumber=1

for column in data:
    if plotnumber<=12:
        ax=plt.subplot(6,6,plotnumber)
        sns.distplot(data[column])
        plt.xlabel(column,fontsize=10)
    
    plotnumber+=1
plt.show()

# %%
third=(q3.alcohol + (1.5 * iqr.alcohol))
third
# Out:
# 13.5

# %%
al=np.where(data['alcohol']>third)

# %%
al
# Out:
# (array([ 961, 1043, 1257, 1258], dtype=int64),)

# %%
data=data.drop(data.index[al])

# %%
data.reset_index()
# Out:
#       index  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0         0            7.4             0.700         0.00             1.9
# 1         1            7.8             0.880         0.00             2.6
# 2         2            7.8             0.760         0.04             2.3
# 3         3           11.2             0.280         0.56             1.9
# 4         4            7.4             0.700         0.00             1.9
# ...     ...            ...               ...          ...             ...
# 1366   1594            6.2             0.600         0.08             2.0
# 1367   1595            5.9             0.550         0.10             2.2
# 1368   1596            6.3             0.510         0.13             2.3
# 1369   1597            5.9             0.645         0.12             2.0
# 1370   1598            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  density    pH  sulphates  alcohol  \
# ...

# %%
fd_feature=data.drop(data['quality'])

# %%
plt.figure(figsize=(20,25),facecolor='yellow')
plotnumber=1

for column in data:
    if plotnumber<=11:
        ax=plt.subplot(6,6,plotnumber)
        sns.distplot(data[column])
        plt.xlabel(column,fontsize=10)
    
    plotnumber+=1
plt.show()

# %%
data.skew()
# Out:
# fixed acidity          0.896895
# volatile acidity       0.386746
# citric acid            0.321902
# residual sugar         2.489185
# chlorides              0.085352
# free sulfur dioxide    0.849794
# density                0.058557
# pH                     0.092832
# sulphates              0.615851
# alcohol                0.749461
# quality                0.315694
# dtype: float64

# %%
data['residual sugar']=np.sqrt(data['residual sugar'])

# %%
data.skew()
# Out:
# fixed acidity          0.896895
# volatile acidity       0.386746
# citric acid            0.321902
# residual sugar         1.851714
# chlorides              0.085352
# free sulfur dioxide    0.849794
# density                0.058557
# pH                     0.092832
# sulphates              0.615851
# alcohol                0.749461
# quality                0.315694
# dtype: float64

# %%
df_feature=data.drop('quality',axis=1)

# %%
plt.figure(figsize=(20,25),facecolor='blue')
graph=1

for column in df_feature:
    if graph<=11:
        ax=plt.subplot(6,5,graph)
        sns.boxplot(data=df_feature[column])
        plt.xlabel(column,fontsize=20)
    
    graph+=1
plt.show()

# %%
plt.figure(figsize=(20,25),facecolor='yellow')
plotnumber=1

for column in data:
    if plotnumber<=11:
        ax=plt.subplot(6,6,plotnumber)
        sns.distplot(data[column])
        plt.xlabel(column,fontsize=10)
    
    plotnumber+=1
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# %%
x = data.drop('quality', axis=1)
y = data['quality']
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=350)
sc = StandardScaler()
X_scaled= sc.fit_transform(x)

# %%
data['quality']=data['quality'].replace({7:1,3:0})
data['quality']=data['quality'].replace({8:1,4:0})
data['quality']=data['quality'].replace({5:0})
data['quality']=data['quality'].replace({6:0})

# %%
for i in data.columns:
    print(data[i].value_counts())
    print("\n")
# Out:
# 7.2     65
# 7.1     55
# 7.8     47
# 7.0     47
# 7.7     46
#         ..
# 5.0      2
# 13.4     1
# 12.1     1
# 5.3      1
# 5.7      1
# Name: fixed acidity, Length: 83, dtype: int64
#
#
# 0.430    41
# 0.600    41
# 0.500    41
# 0.590    37
# 0.580    35
#          ..
# 0.845     1
# 0.805     1
# 0.625     1
# 0.825     1
# 0.865     1
# Name: volatile acidity, Length: 132, dtype: int64
#
#
# 0.00    107
# 0.49     54
# 0.02     46
# 0.24     46
# 0.10     34
#        ...
# 0.62      1
# 0.72      1
# 0.67      1
# 0.70      1
# 0.75      1
# Name: citric acid, Length: 76, dtype: int64
#
#
# 1.122462    141
# 1.131627    116
# 1.140435    112
# 1.112907    106
# 1.102924    101
#            ...
# 1.314119      1
# 1.168844      1
# 1.136073      1
# 1.373027      1
# 1.336531      1
# Name: residual sugar, Length: 66, dtype: int64
#
#
# 0.080    63
# 0.074    51
# 0.076    50
# 0.078    49
# 0.084    47
#          ..
# 0.038     2
# 0.041     2
# 0.108     1
# 0.043     1
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfr=RandomForestClassifier()

# %%
rfr.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
pred=rfr.predict(X_test)
pred
# Out:
# array([6, 6, 5, 6, 5, 5, 5, 5, 6, 6, 7, 5, 7, 5, 5, 6, 5, 7, 5, 5, 6, 6,
#        6, 5, 5, 6, 6, 7, 6, 6, 5, 6, 6, 5, 6, 5, 6, 7, 6, 6, 5, 6, 5, 5,
#        6, 6, 6, 5, 6, 5, 5, 5, 5, 5, 7, 5, 5, 5, 7, 5, 6, 5, 6, 6, 6, 6,
#        6, 5, 5, 7, 7, 5, 6, 6, 5, 5, 6, 6, 7, 6, 5, 6, 6, 6, 5, 6, 6, 5,
#        6, 6, 6, 5, 6, 5, 6, 6, 5, 5, 5, 6, 5, 6, 5, 5, 5, 5, 6, 6, 5, 5,
#        5, 6, 5, 5, 5, 6, 5, 5, 6, 6, 5, 6, 5, 5, 7, 5, 6, 5, 5, 6, 6, 5,
#        5, 6, 5, 6, 6, 5, 5, 5, 5, 5, 6, 7, 5, 5, 6, 5, 6, 7, 5, 5, 6, 6,
#        5, 6, 6, 5, 7, 6, 6, 6, 7, 7, 6, 5, 5, 5, 5, 5, 7, 6, 6, 6, 6, 5,
#        6, 5, 5, 5, 5, 6, 5, 5, 5, 6, 6, 5, 7, 6, 5, 6, 6, 7, 5, 6, 6, 6,
#        5, 6, 5, 5, 6, 5, 5, 5, 5, 6, 6, 5, 5, 6, 5, 5, 6, 5, 6, 5, 6, 6,
#        6, 5, 6, 6, 6, 7, 6, 6, 5, 6, 5, 5, 5, 6, 6, 6, 8, 6, 7, 7, 5, 5,
#        5, 6, 6, 6, 6, 5, 6, 6, 5, 5, 6, 6, 6, 7, 5, 5, 5, 6, 6, 7, 5, 5,
#        6, 6, 6, 6, 6, 5, 6, 5, 7, 7, 7], dtype=int64)

# %%
acc=accuracy_score(y_test,pred)
acc
# Out:
# 0.6872727272727273

# %%
from sklearn.model_selection import cross_val_score

# %%
score=cross_val_score(rfr,x,y)
print(score)
print(score.mean())
print(acc-score.mean())
# Out:
# [0.49090909 0.57664234 0.62043796 0.58394161 0.55109489]
# 0.5646051758460517
# 0.12266755142667551
